# %%
#Regression-5 Assignment
"""Q1. What is Elastic Net Regression and how does it differ from other regression techniques?"""
Ans:  Elastic Net Regression is a regularized regression technique that combines the properties of both Ridge and Lasso
regression. It adds a penalty term to the loss function that is a combination of the L1 and L2 penalties from Ridge and 
Lasso respectively. This allows it to select important features while also shrinking the coefficients of less important
ones to reduce overfitting. It differs from other regression techniques in that it combines the properties of both
Ridge and Lasso regression, allowing it to select important features while also shrinking the coefficients of less 
important ones.

"""Q2. How do you choose the optimal values of the regularization parameters for Elastic Net Regression?"""
Ans: The optimal values of the regularization parameters for Elastic Net Regression can be chosen using cross-validation.
Cross-validation is a technique used to evaluate predictive models by partitioning the data into a training set to train
the model, and a test set to evaluate it. The model is then evaluated by computing the error rate on the test set. The 
regularization parameters can then be tuned to minimize the error rate on the test set.

"""Q3. What are the advantages and disadvantages of Elastic Net Regression?"""
Ans: Advantages: 
1. Elastic Net Regression is a combination of Ridge and Lasso regression, which means it can perform both feature 
selection and regularization. This allows for better accuracy in predictions. 
2. It can handle high-dimensional data sets with many features, which is useful for complex data sets.
3. It can also handle collinearity better than other regression models, which is important when dealing with correlated
features.

Disadvantages: 
1. Elastic Net Regression can be computationally expensive, as it requires more iterations to find the optimal solution.
2. It can be difficult to interpret the results, as the coefficients are a combination of both Ridge and Lasso 
regression.
3. It is also sensitive to outliers, which can lead to inaccurate predictions.

"""Q4. What are some common use cases for Elastic Net Regression?"""
Ans: Common use cases for Elastic Net Regression include predicting customer churn, forecasting sales, predicting stock 
prices, and predicting credit risk. It can also be used to identify important features in a dataset and to reduce the
complexity of a model.

"""Q5. How do you interpret the coefficients in Elastic Net Regression?"""
Ans: The coefficients in Elastic Net Regression represent the amount of influence that each feature has on the outcome. 
The larger the coefficient, the more influence that feature has on the outcome. The sign of the coefficient indicates
whether a feature has a positive or negative effect on the outcome. Positive coefficients indicate that an increase in 
the feature will lead to an increase in the outcome, while negative coefficients indicate that an increase in the 
feature will lead to a decrease in the outcome.

"""Q6. How do you handle missing values when using Elastic Net Regression?"""
Ans: When using Elastic Net Regression, missing values can be handled by imputing the missing values with the mean or
median of the data set. Alternatively, if the data set is large enough, it may be possible to use a more sophisticated 
imputation technique such as multiple imputation.

"""Q7. How do you use Elastic Net Regression for feature selection?"""
Ans: Elastic Net Regression is a regularization technique that combines the properties of both Ridge and Lasso 
regression. It can be used for feature selection by setting the regularization parameter to a high value, which will 
shrink the coefficients of less important features to zero. This will effectively remove those features from the model,
leaving only the most important features.

"""Q8. How do you pickle and unpickle a trained Elastic Net Regression model in Python?"""
Ans: Pickling:

To pickle a trained Elastic Net Regression model in Python, you can use the pickle library. First, import the pickle 
library and then use the dump() method to serialize the model object into a file.

import pickle 
pickle.dump(model, open("elastic_net_model.pkl", "wb"))

Unpickling:

To unpickle a trained Elastic Net Regression model in Python, you can use the pickle library. First, import the pickle 
library and then use the load() method to deserialize the model object from a file.

import pickle 
model = pickle.load(open("elastic_net_model.pkl", "rb"))

"""Q9. What is the purpose of pickling a model in machine learning?"""
Ans: Pickling a model in machine learning is the process of saving a trained model to disk so that it can be loaded 
later and used for making predictions. This allows models to be reused without having to retrain them each time.

Pickling also allows models to be shared between different programming languages, as the pickled model can be loaded in 
any language that supports the pickle library.
